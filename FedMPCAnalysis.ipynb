# %% [markdown]
# ##FED MPC Analysis

# %%
from experiment_result import ExperimentResult, load_experiments_from_csv
import matplotlib.pyplot as plt
import numpy as np
import niid_bench.utils_postprocess as utils_pp

# %%
csv_file_path = "experiments_fl.csv"
experiments = load_experiments_from_csv(csv_file_path)

print(len(experiments))
# Out:
# [Errno 2] No such file or directory: 'nan/centralized_metrics.csv'
# [Errno 2] No such file or directory: 'nan/centralized_metrics.csv'
# 154

# %%
# Define filter criteria
filter_criteria = {
    "ID": 152 
}

# Apply the single filter and plot the results

filtered_experiments = utils_pp.filter_experiments(experiments, filter_criteria)

print(len(filtered_experiments))
#plot_centralized_metrics(filtered_experiments, title="Accuracy Over Rounds - MNIST FedAvg Label Quantity")
#utils_pp.plot_centralized_metrics(filtered_experiments, title="Experiment Results", metric = 'centralized_accuracy')
#utils_pp.plot_distributed_metrics(filtered_experiments, title="Experiment Results", metric = 'distributed_test_loss')

exp = filtered_experiments[0]
key = 'centralized_metrics'
getattr(exp, key)
# Out:
# 1
#     accuracy  round  fraction_fit  fraction_fit_prev  \
# 0     0.1002      1      0.500000                NaN
# 1     0.1248      2      0.186147           0.500000
# 2     0.2186      3      0.269207           0.186147
# 3     0.2248      4      0.269207           0.269207
# 4     0.2663      5      0.305488           0.269207
# 5     0.2697      6      0.305488           0.305488
# 6     0.3054      7      0.320782           0.305488
# 7     0.3408      8      0.320782           0.320782
# 8     0.3616      9      0.320782           0.320782
# 9     0.3692     10      0.354306           0.320782
# 10    0.3902     11      0.300534           0.354306
# 11    0.4044     12      0.412404           0.300534
# 12    0.4151     13      0.441970           0.412404
# 13    0.4300     14      0.412404           0.441970
# 14    0.4411     15      0.412404           0.412404
# 15    0.4450     16      0.407393           0.412404
# 16    0.4562     17      0.460652           0.407393
# 17    0.4650     18      0.460652           0.460652
# 18    0.4707     19      0.412404           0.460652
# 19    0.4802     20      0.362730           0.412404
# 20    0.4829     21      0.460652           0.362730
# 21    0.4839     22      0.348970           0.460652
# 22    0.4960     23      0.460652           0.348970
# 23    0.5035     24      0.348970           0.460652
# 24    0.5103     25      0.413446           0.348970
# 25    0.5040     26      0.348970           0.413446
# 26    0.5094     27      0.348970           0.348970
# 27    0.5182     28      0.348970           0.348970
# 28    0.5236     29      0.348970           0.348970
# 29    0.5249     30      0.348970           0.348970
# 30    0.5267     31      0.348970           0.348970
# 31    0.5334     32      0.348970           0.348970
# 32    0.5268     33      0.348970           0.348970
# 33    0.5230     34      0.348970           0.348970
# 34    0.5432     35      0.414582           0.348970
# 35    0.5413     36      0.348970           0.414582
# 36    0.5438     37      0.348970           0.348970
# 37    0.5503     38      0.348970           0.348970
# 38    0.5504     39      0.348970           0.348970
# 39    0.5511     40      0.348970           0.348970
# 40    0.5559     41      0.348970           0.348970
# 41    0.5577     42      0.348970           0.348970
# 42    0.5645     43      0.348970           0.348970
# 53                     0.5863                0.5855            0.624378
# 54                     0.5855                0.5886            0.628653
# 55                     0.5886                0.5910            0.633113
# 56                     0.5910                0.5863            0.628854
# 57                     0.5863                0.5900            0.633099
# 58                     0.5900                0.5879            0.638275
# 59                     0.5879                0.5923            0.643213

# %%
# Ensure both columns exist
df = exp.centralized_metrics
if "centralized_accuracy" in df.columns and "predicted_accuracy" in df.columns:
    df = df.dropna(subset=["centralized_accuracy", "predicted_accuracy"])

    # 📈 Line Plot
    plt.figure(figsize=(8, 5))
    plt.plot(df["centralized_accuracy"], label="Centralized Accuracy", marker='o')
    plt.plot(df["predicted_accuracy"], label="Predicted Accuracy", marker='x')
    plt.title("Centralized vs Predicted Accuracy")
    plt.xlabel("Round")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

else:
    print("⚠️ Required columns not found in centralized_metrics.")

# %%
# Define filter criteria
filter_criteria = {
    "ID": [160,153]
     
}

# Apply the single filter and plot the results

filtered_experiments = utils_pp.filter_experiments(experiments, filter_criteria)

print(len(filtered_experiments))
utils_pp.plot_centralized_metrics(filtered_experiments, title="Accuracy Over Rounds - MNIST FedAvg Label Quantity")
#utils_pp.plot_centralized_metrics(filtered_experiments, title="Experiment Results", metric = 'centralized_accuracy')
#utils_pp.plot_distributed_metrics(filtered_experiments, title="Experiment Results", metric = 'distributed_test_loss')

# exp = filtered_experiments[0]
# key = 'centralized_metrics'
# getattr(exp, key)
# Out:
# 2

# %%
# Define filter criteria
filter_criteria = {
    "ID": 150 
}

# Apply the single filter and plot the results

filtered_experiments = utils_pp.filter_experiments(experiments, filter_criteria)

print(len(filtered_experiments))
#plot_centralized_metrics(filtered_experiments, title="Accuracy Over Rounds - MNIST FedAvg Label Quantity")
#utils_pp.plot_centralized_metrics(filtered_experiments, title="Experiment Results", metric = 'centralized_accuracy')
#utils_pp.plot_distributed_metrics(filtered_experiments, title="Experiment Results", metric = 'distributed_test_loss')

exp = filtered_experiments[0]
key = 'centralized_metrics'
getattr(exp, key)
# Out:
# 1
#    accuracy  round  fraction_fit  fraction_fit_prev  \
# 0    0.1046      1      0.500000                NaN
# 1    0.1117      2      0.186147           0.500000
# 2    0.2256      3      0.269207           0.186147
# 3    0.2370      4      0.346895           0.269207
# 4    0.2635      5      0.305488           0.346895
# 5    0.2780      6      0.305488           0.305488
# 6    0.2870      7      0.320782           0.305488
# 7    0.3262      8      0.320782           0.320782
# 8    0.3475      9      0.276810           0.320782
# 9    0.3662     10      0.276810           0.276810
#
#    centralized_accuracy_prev  centralized_accuracy  predicted_accuracy
# 0                        NaN                0.1046                 NaN
# 1                     0.1046                0.1117            0.234679
# 2                     0.1117                0.2256            0.239563
# 3                     0.2256                0.2370            0.290347
# 4                     0.2370                0.2635            0.303388
# 5                     0.2635                0.2780            0.320920
# 6                     0.2780                0.2870            0.336646
# 7                     0.2870                0.3262            0.354154
# 8                     0.3262                0.3475            0.375059
# 9                     0.3475                0.3662            0.387739

# %%
csv_file_path = "experiments_fl.csv"
experiments = load_experiments_from_csv(csv_file_path)

print(len(experiments))
# Out:
# [Errno 2] No such file or directory: 'nan/centralized_metrics.csv'
# [Errno 2] No such file or directory: 'nan/centralized_metrics.csv'
# 152

# %%
# Define filter criteria
filter_criteria = {
    "ID": 160 
}

# Apply the single filter and plot the results

filtered_experiments = utils_pp.filter_experiments(experiments, filter_criteria)

print(len(filtered_experiments))
#plot_centralized_metrics(filtered_experiments, title="Accuracy Over Rounds - MNIST FedAvg Label Quantity")
#utils_pp.plot_centralized_metrics(filtered_experiments, title="Experiment Results", metric = 'centralized_accuracy')
#utils_pp.plot_distributed_metrics(filtered_experiments, title="Experiment Results", metric = 'distributed_test_loss')

exp = filtered_experiments[0]
key = 'centralized_metrics'
getattr(exp, key)
# Out:
# 1
#     accuracy  round  fraction_fit  fraction_fit_prev  \
# 0     0.1364      1      0.900000                NaN
# 1     0.1689      2      0.900000           0.900000
# 2     0.2310      3      0.900000           0.900000
# 3     0.2591      4      0.900000           0.900000
# 4     0.2672      5      0.900000           0.900000
# 5     0.2595      6      0.108277           0.900000
# 6     0.3048      7      0.108277           0.108277
# 7     0.3186      8      0.108277           0.108277
# 8     0.3552      9      0.108277           0.108277
# 9     0.3657     10      0.108277           0.108277
# 10    0.3951     11      0.108277           0.108277
# 11    0.4182     12      0.108277           0.108277
# 12    0.3936     13      0.108277           0.108277
# 13    0.4258     14      0.108277           0.108277
# 14    0.4296     15      0.108277           0.108277
# 15    0.4419     16      0.108277           0.108277
# 16    0.4369     17      0.108277           0.108277
# 17    0.4597     18      0.108277           0.108277
# 18    0.4562     19      0.108277           0.108277
# 19    0.4819     20      0.108277           0.108277
# 20    0.4803     21      0.108277           0.108277
# 21    0.4765     22      0.108277           0.108277
# 22    0.4828     23      0.108277           0.108277
# 23    0.4858     24      0.108277           0.108277
# 24    0.5016     25      0.108277           0.108277
# 25    0.5063     26      0.108277           0.108277
# 26    0.5141     27      0.108277           0.108277
# 27    0.5042     28      0.108277           0.108277
# 28    0.5051     29      0.108277           0.108277
# 29    0.4985     30      0.108277           0.108277
# 30    0.5190     31      0.108277           0.108277
# 31    0.5232     32      0.108277           0.108277
# 32    0.5232     33      0.108277           0.108277
# 33    0.5262     34      0.108277           0.108277
# 34    0.5242     35      0.108277           0.108277
# 35    0.5252     36      0.108277           0.108277
# 36    0.5360     37      0.108277           0.108277
# 37    0.5204     38      0.108277           0.108277
# 38    0.5262     39      0.108277           0.108277
# 39    0.5394     40      0.108277           0.108277
# 40    0.5372     41      0.108277           0.108277
# 41    0.5254     42      0.108277           0.108277
# 42    0.5319     43      0.108277           0.108277
# 43    0.5456     44      0.108277           0.108277
# 44    0.5482     45      0.108277           0.108277
# 45    0.5052     46      0.108277           0.108277
# 46    0.5513     47      0.108277           0.108277
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4          0.03518
# 5          0.02174
# 6          0.01480
# 7          0.01566
# 8          0.02351
# 9          0.02628
# 10         0.02277
# 11         0.02391
# 12         0.01293
# 13         0.01187
# 14         0.00766
# 15         0.00834
# 16         0.01027
# 17         0.00751
# 18         0.00710
# 19         0.00993
# 20         0.01090
# 21         0.00577
# 22         0.00478
# 23         0.00103
# 24         0.00519
# 25         0.00784
# 26         0.00831
# 27         0.00493
# 28         0.00049
# 29        -0.00246
# 30         0.00041
# 31         0.00519
# 32         0.00609
# 33         0.00596
# 34         0.00134
# 35         0.00050
# 36         0.00246
# 37         0.00002
# 38        -0.00008
# 39         0.00186
# 40         0.00214
# 41         0.00210
# 42        -0.00026
# 43         0.00071
# 44         0.00422
# 45        -0.00241
# 46        -0.00016
# 47         0.00453
# 48         0.00967
# 49         0.01387
# 50         0.00118
# 51        -0.00467
# 52        -0.00379
# 53        -0.00455
# 54        -0.00113
# 55         0.00130
# 56         0.00307
# 57         0.00650
# 58         0.00255
# 59         0.00190

# %%
# Ensure both columns exist
df = exp.centralized_metrics
if "centralized_accuracy" in df.columns and "predicted_accuracy" in df.columns:
    df = df.dropna(subset=["centralized_accuracy", "predicted_accuracy"])

    # 📈 Line Plot
    plt.figure(figsize=(8, 5))
    plt.plot(df["centralized_accuracy"], label="Centralized Accuracy", marker='o')
    plt.plot(df["predicted_accuracy"], label="Predicted Accuracy", marker='x')
    plt.title("Centralized vs Predicted Accuracy")
    plt.xlabel("Round")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

else:
    print("⚠️ Required columns not found in centralized_metrics.")

# %%
# Define filter criteria
filter_criteria = {
    "ID": [152,158]
     
}

# Apply the single filter and plot the results

filtered_experiments = utils_pp.filter_experiments(experiments, filter_criteria)

print(len(filtered_experiments))
utils_pp.plot_centralized_metrics(filtered_experiments, title="Accuracy Over Rounds - MNIST FedAvg Label Quantity")
#utils_pp.plot_centralized_metrics(filtered_experiments, title="Experiment Results", metric = 'centralized_accuracy')
#utils_pp.plot_distributed_metrics(filtered_experiments, title="Experiment Results", metric = 'distributed_test_loss')

# exp = filtered_experiments[0]
# key = 'centralized_metrics'
# getattr(exp, key)
# Out:
# 2

# %%
# Define filter criteria
filter_criteria = {
    "ID": [158,160]
     
}

# Apply the single filter and plot the results

filtered_experiments = utils_pp.filter_experiments(experiments, filter_criteria)

print(len(filtered_experiments))
utils_pp.plot_centralized_metrics(filtered_experiments, title="Accuracy Over Rounds - MNIST FedAvg Label Quantity")
#utils_pp.plot_centralized_metrics(filtered_experiments, title="Experiment Results", metric = 'centralized_accuracy')
#utils_pp.plot_distributed_metrics(filtered_experiments, title="Experiment Results", metric = 'distributed_test_loss')

# exp = filtered_experiments[0]
# key = 'centralized_metrics'
# getattr(exp, key)
# Out:
# 2
